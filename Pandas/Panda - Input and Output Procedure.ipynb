# %%
# We are basically working with 4 kinds of file 
# CSV
# Excel
# HTML
# SQL
# In order to work with SQL databases and HTML files we need to install following packages
# conda install sqlalchemy
# conda install lxml
# conda install html5lib
# conda install BeautifulSoup4

# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\bhada\\Downloads\\Python_DataScience\\Python-Data-Science-and-Machine-Learning-Bootcamp\\Python-Data-Science-and-Machine-Learning-Bootcamp'

# %%
df = pd.read_csv('jobs.csv')

# %%
df.head()
# Out:
#                                hash  company_id  \
# 0  000001a5f7022973b3d8b7b2c3e24082         420
# 1  000005782bc4ce081dd656ee55b405b2       17976
# 2  000010b1e01a832cd8e725f9552ff9ba        9208
# 3  000011518dfb25f79fdddc85376099e2       12084
# 4  000014a0c96182242b75a1ba47a1b582         420
#
#                       company_name  \
# 0                             SAIC
# 1                            Emcor
# 2  Wyndham Hotels and Resorts  LLC
# 3                Fluor Corporation
# 4                             SAIC
#
#                                                title created_date  \
# 0                         Sr. Environmental Engineer   2008-12-01
# 1                               Carpenter Journeyman   2010-03-17
# 2  Guest Services Associate - Wyndham Arrow Point...   2015-05-28
# 3                         Principal HR/IR Technician   2016-06-03
# 4                                 Test Engineer (OS)   2008-12-15
#
# ...

# %%
# method to write back to a csv file, you can use to_csv method for the same
df.head().to_csv('My_output',index=False)

# %%
pd.read_csv('My_output')
# Out:
#                                hash  company_id  \
# 0  000001a5f7022973b3d8b7b2c3e24082         420
# 1  000005782bc4ce081dd656ee55b405b2       17976
# 2  000010b1e01a832cd8e725f9552ff9ba        9208
# 3  000011518dfb25f79fdddc85376099e2       12084
# 4  000014a0c96182242b75a1ba47a1b582         420
#
#                       company_name  \
# 0                             SAIC
# 1                            Emcor
# 2  Wyndham Hotels and Resorts  LLC
# 3                Fluor Corporation
# 4                             SAIC
#
#                                                title created_date  \
# 0                         Sr. Environmental Engineer   2008-12-01
# 1                               Carpenter Journeyman   2010-03-17
# 2  Guest Services Associate - Wyndham Arrow Point...   2015-05-28
# 3                         Principal HR/IR Technician   2016-06-03
# 4                                 Test Engineer (OS)   2008-12-15
#
# ...

# %%
# Now let us see how to use excel file for reading and writing purpose

pd.read_excel('example_excel.xlsx',sheetname='Sheet1')
# Note similarly we can use to_excel for writing the data from dataframe to excel file
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# How to scrape data from html page or web

data = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
data[0].head()
# Out:
#                                            Bank Name                City  ST  \
# 0  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 1                                     First NBC Bank         New Orleans  LA
# 2                                      Proficio Bank  Cottonwood Heights  UT
# 3                      Seaway Bank and Trust Company             Chicago  IL
# 4                             Harvest Community Bank          Pennsville  NJ
#
#     CERT                Acquiring Institution      Closing Date  \
# 0  30003  First-Citizens Bank & Trust Company       May 5, 2017
# 1  58302                         Whitney Bank    April 28, 2017
# 2  35495                    Cache Valley Bank     March 3, 2017
# 3  19328                  State Bank of Texas  January 27, 2017
# 4  34951  First-Citizens Bank & Trust Company  January 13, 2017
#
#      Updated Date
# 0    May 11, 2017
# 1    May 10, 2017
# 2  April 13, 2017
# 3  April 21, 2017
# 4  April 13, 2017

# %%
# type of the data is 
type(data)
# Out:
# list

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df
# Out:
#                                      hash  company_id  \
# 0        000001a5f7022973b3d8b7b2c3e24082         420
# 1        000005782bc4ce081dd656ee55b405b2       17976
# 2        000010b1e01a832cd8e725f9552ff9ba        9208
# 3        000011518dfb25f79fdddc85376099e2       12084
# 4        000014a0c96182242b75a1ba47a1b582         420
# 5        000015ac5f0a9bb6806abb85141529cf       39260
# 6        00001eb6c29012c28227bcd454d70212        2939
# 7        0000224a92429f0c139e46768c503f7a         420
# 8        000023c7ad277ac7dc06f26fe62f6067        1889
# 9        000025301e0c620fb51a3e565ca63362         420
# 10       0000258a3c2ca68fe10dfb8c3e6940a3        9208
# 11       000026e022fe7c2c5f4c3dc08140a28f        8876
# 12       000027b5fe16db92685def6de3399c2a         420
# 13       00002946a46f52e9af0fa4799059fbef        3560
# 14       00002fcec290456377cfa8d025f03887         420
# 15       00003a071b0e248969e2e33014626b5e        9036
# ...

# %%
df = pd.read_excel('example_excel.xlsx',sheetname='Sheet1')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_sql('my_table',engine)

# %%
sqldf = pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
# note we can see that the axes are iterable and thus we can loop over it

# for current_ax in axes:
#     current_ax.plot(x,y)
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000260A1E16C50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000260A20184A8>], dtype=object)

# %%
x =  np.linspace(0,5,11)
y = x ** 2

# %%
fig,axes = plt.subplots(nrows=2,ncols=4)
plt.tight_layout()
